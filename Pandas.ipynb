# %%
import pandas as pd

# %%
df = pd.read_csv('https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
df2 = pd.DataFrame.from_dict({'a':[1,2], 'b':[3,4]})

# %%
df2
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df.to_csv('tmp.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Lname        156 non-null    object
#  4   Name         156 non-null    object
#  5   Sex          156 non-null    object
#  6   Age          126 non-null    float64
#  7   SibSp        156 non-null    int64
#  8   Parch        156 non-null    int64
#  9   Ticket       156 non-null    object
#  10  Fare         156 non-null    float64
#  11  Cabin        31 non-null     object
#  12  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 16.0+ KB

# %%
# узнать количество строк и столбцов
df.shape
# Out:
# (156, 13)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass         Lname                Name   Sex  \
# 153          154         0       3  van Billiard   Mr. Austin Blyler  male
# 154          155         0       3         Olsen      Mr. Ole Martin  male
# 155          156         0       1      Williams   Mr. Charles Duane  male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 153  40.5      0      2   A/5. 851  14.5000   NaN        S
# 154   NaN      0      0  Fa 265302   7.3125   NaN        S
# 155  51.0      0      1   PC 17597  61.3792   NaN        C

# %%
# чтобы получить все типы данных
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# фильтровка данных по имени
df['Name']
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 151                     Mrs. Thomas (Edith Wearne)
# 152                                    Mr. Alfonzo
# 153                              Mr. Austin Blyler
# 154                                 Mr. Ole Martin
# 155                              Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
# показать количество строк
df['Name'].shape
# Out:
# (156,)

# %%
# хотим взять только имя и возраст по первым трем записям
# квадратные скобки двойные, т.е. вводим как список
df[['Name', 'Age']].head(3)
# Out:
#                                           Name   Age
# 0                              Mr. Owen Harris  22.0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  38.0
# 2                                  Miss. Laina  26.0

# %%
# чтобы взять только определенные строки и столбцы
df.loc[[5, 10, 15], ['Name','Age']]
# Out:
#                         Name   Age
# 5                  Mr. James   NaN
# 10      Miss. Marguerite Rut   4.0
# 15   Mrs. (Mary D Kingcome)   55.0

# %%
# если выбирать определенные значения по индексу
df.iloc[[5, 10, 15], [0, 1]]
# Out:
#     PassengerId  Survived
# 5             6         0
# 10           11         1
# 15           16         1

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# выбрать данные из таблицы по срезам
df.iloc[5:11, :3]
# Out:
#     PassengerId  Survived  Pclass
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3

# %%
# ФИЛЬТРОВКА ДАННЫХ

# %%
# внутри квадрантных скобок указываем булевую маску
df[df['Age'] > 18]
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 150          151         0       2       Bateman
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
df['Age'] > 18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151     True
# 152     True
# 153     True
# 154    False
# 155     True
# Name: Age, Length: 156, dtype: bool

# %%
# функция isin которая позволяет сравнить с множеством объектов
df[df['Age'].isin([5, 10, 15])]
# Out:
#     PassengerId  Survived  Pclass    Lname                     Name     Sex  \
# 22           23         1       3  McGowan               Miss. Anna  female
# 58           59         1       2     West   Miss. Constance Mirium  female
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 22  15.0      0      0      330923   8.0292   NaN        Q
# 58   5.0      1      2  C.A. 34651  27.7500   NaN        S

# %%
df[df['Age'] == 10]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Lname, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# выбрать пассажиров возрастом 5 или 10 лет 
# при помощи булевых значений
# каждую булевую операцию берем в скобки
# прямая палочка - оператор 'или', & - оператор 'и'

df[(df['Age'] == 5) | (df['Age'] == 10)]
# Out:
#     PassengerId  Survived  Pclass Lname                     Name     Sex  Age  \
# 58           59         1       2  West   Miss. Constance Mirium  female  5.0
#
#     SibSp  Parch      Ticket   Fare Cabin Embarked
# 58      1      2  C.A. 34651  27.75   NaN        S

# %%
# проверка есть ли на этом месте элемент
df['Age'].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151     True
# 152     True
# 153     True
# 154    False
# 155     True
# Name: Age, Length: 156, dtype: bool

# %%
# отфильтруем данные, чтобы там не было пропусков по возрасту
df[df['Age'].notna()]
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 150          151         0       2       Bateman
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
# наоборот определим, является ли элемент пустым
df['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
# также соберем набор данных только из тех значений, где есть пропуски
df['Age'].isna().sum()
# Out:
# 30

# %%
# вывести имя людей, для которых мы знаем возраст
df.loc[df['Age'].notna(), 'Name']
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 150                              Rev. Robert James
# 151                     Mrs. Thomas (Edith Wearne)
# 152                                    Mr. Alfonzo
# 153                              Mr. Austin Blyler
# 155                              Mr. Charles Duane
# Name: Name, Length: 126, dtype: object

# %%
# СОРТИРОВКА ДАННЫХ

# %%
# отсортируем людей по возрасту
df.sort_values('Age').head(10)
# Out:
#      PassengerId  Survived  Pclass      Lname  \
# 78            79         1       2   Caldwell
# 119          120         0       3  Andersson
# 7              8         0       3    Palsson
# 16            17         0       3       Rice
# 43            44         1       2    Laroche
# 63            64         0       3      Skoog
# 10            11         1       3  Sandstrom
# 58            59         1       2       West
# 50            51         0       3     Panula
# 24            25         0       3    Palsson
#
#                                  Name     Sex   Age  SibSp  Parch  \
# 78                Master. Alden Gates    male  0.83      0      2
# 119            Miss. Ellis Anna Maria  female  2.00      4      2
# 7               Master. Gosta Leonard    male  2.00      3      1
# 16                     Master. Eugene    male  2.00      4      1
# 43    Miss. Simonne Marie Anne Andree  female  3.00      1      2
# ...

# %%
# отсортируем людей по возрасту в обратном порядке
# если по возрасту одинаковые то сортировка по имени
# false - для возраста и true - для имени
df.sort_values(['Age', 'Name'], ascending = [False, True]).head(10)
# Out:
#      PassengerId  Survived  Pclass        Lname                      Name  \
# 96            97         0       1  Goldschmidt              Mr. George B
# 116          117         0       3      Connors               Mr. Patrick
# 33            34         0       2      Wheadon              Mr. Edward H
# 54            55         0       1        Ostby   Mr. Engelhart Cornelius
# 94            95         0       3        Coxon                Mr. Daniel
# 11            12         1       1      Bonnell           Miss. Elizabeth
# 152          153         0       3          Meo               Mr. Alfonzo
# 15            16         1       2      Hewlett   Mrs. (Mary D Kingcome)
# 124          125         0       1        White      Mr. Percival Wayland
# 6              7         0       1     McCarthy             Mr. Timothy J
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 96     male  71.0      0      0    PC 17754  34.6542    A5        C
# ...

# %%
# ОБЪЕДИНЕНИЕ DATAFRAMES

# %%
# deep=True копируется не только ссылка а все элементы
df2 = df.copy(deep=True)

# %%
# конкатенация - первый способ объединения (по строкам, т.е. строки второго датафрейма прибавляем к строкам первого датафрейма)
cdf1 = pd.concat([df, df2])
# посмотрим размер нового датафрейма
cdf1.shape
# Out:
# (312, 13)

# %%
df.shape
# Out:
# (156, 13)

# %%
# конкатенация - второй способ объединения (по столбцам)
cdf2 = pd.concat([df, df2], axis=1)
# посмотрим размер нового датафрейма
cdf2.shape
# Out:
# (156, 26)

# %%
# функция join

# %%
mdf = pd.DataFrame(index=df.index)
mdf['PassengerId'] = df['PassengerId']
mdf['evenId'] = mdf['PassengerId'].apply(lambda x: x % 2 == 0)

# %%
mdf
# Out:
#      PassengerId  evenId
# 0              1   False
# 1              2    True
# 2              3   False
# 3              4    True
# 4              5   False
# ..           ...     ...
# 151          152    True
# 152          153   False
# 153          154    True
# 154          155   False
# 155          156    True
#
# [156 rows x 2 columns]

# %%
# сджойним два датафрема при помощи функции merge
pd.merge(df, mdf, how='inner')
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
# АНАЛИТИЧЕСКИЕ ФУНКЦИИ

# %%
# посчитаем количество ненулевых элементов
df.count()
# Out:
# PassengerId    156
# Survived       156
# Pclass         156
# Lname          156
# Name           156
# Sex            156
# Age            126
# SibSp          156
# Parch          156
# Ticket         156
# Fare           156
# Cabin           31
# Embarked       155
# dtype: int64

# %%
df['Age'].count()
# Out:
# 126

# %%
# посчитаем среднее и медиану
df['Age'].mean(), df['Age'].median()
# Out:
# (28.141507936507935, 26.0)

# %%
# выведем сразу несколько статистических параметров
df['Age'].describe()
# Out:
# count    126.000000
# mean      28.141508
# std       14.613880
# min        0.830000
# 25%       19.000000
# 50%       26.000000
# 75%       35.000000
# max       71.000000
# Name: Age, dtype: float64

# %%
# сгруппировать данные по какой-либо колонке groupby()
# посчитать средний возраст для отдельных категорий 
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    24.468085
# male      30.326962
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%    75%   max
# Sex
# female   47.0  24.468085  12.930586  2.00  16.5  22.0  31.75  58.0
# male     79.0  30.326962  15.188113  0.83  21.0  28.0  37.50  71.0

# %%
df.groupby(['Sex', 'Survived'])['Age'].agg(['mean', 'median'])
# Out:
#                       mean  median
# Sex    Survived
# female 0         20.633333    18.0
#        1         26.265625    25.0
# male   0         31.228571    28.0
#        1         23.314444    27.0

# %%
# value_counts - позволяет посчитать количество элементов каждой группы
# посчитать сколько мужчин и сколько женщин
df['Sex'].value_counts()
# Out:
# Sex
# male      100
# female     56
# Name: count, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female     56
# male      100
# Name: Sex, dtype: int64

# %%
# функция корреляции - чтобы понять как данные зависят друг от друга
# df.corr()

# %%
# ВИЗУАЛИЗАЦИ

# %%
# построить гистограмму распределения возраста

# %%
df['Age'].plot(kind='hist', bins=20)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde', xlim=[0,100])
# Out:
# <Axes: ylabel='Density'>

# %%
df.groupby('Sex')['Age'].plot(kind='kde', xlim=[0,100], legend=True)
# Out:
# Sex
# female    Axes(0.125,0.11;0.775x0.77)
# male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
# КАК ИЗМЕНЯТЬ ДАННЫЕ В ДАТАФРЕЙМАХ

# %%
tmp_df = df.copy(deep=True)

# %%
# можно просто присвоить константное значение какой-либо колонке
tmp_df['Pclass'] = 1

# %%
tmp_df['Pclass'].value_counts() # для нового датафрейма
# Out:
# Pclass
# 1    156
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts() # для старого датафрейма
# Out:
# Pclass
# 3    96
# 1    30
# 2    30
# Name: count, dtype: int64

# %%
# создание новой колонки
tmp_df['isAdult'] = tmp_df['Age'] >= 18
tmp_df.head(10)
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       1     Braund
# 1            2         1       1    Cumings
# 2            3         1       1  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       1      Allen
# 5            6         0       1      Moran
# 6            7         0       1   McCarthy
# 7            8         0       1    Palsson
# 8            9         1       1    Johnson
# 9           10         1       1     Nasser
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
# ...

# %%
# можем менять значения только для каких-то отдельных записей
# человек выжил и он взрослый
tmp_df['isAdultSurvived'] = tmp_df['isAdult']
tmp_df.loc[tmp_df['Survived'] == 0, 'isAdultSurvived'] = False

# %%
tmp_df.head(10)
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       1     Braund
# 1            2         1       1    Cumings
# 2            3         1       1  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       1      Allen
# 5            6         0       1      Moran
# 6            7         0       1   McCarthy
# 7            8         0       1    Palsson
# 8            9         1       1    Johnson
# 9           10         1       1     Nasser
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
# ...

# %%
# можно переименовать просто название колонок
tmp_df.rename(
    columns={'isAdultSurvived': 'AdultSurvived'}
).head(1)
# Out:
#    PassengerId  Survived  Pclass   Lname              Name   Sex   Age  SibSp  \
# 0            1         0       1  Braund   Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  isAdult  AdultSurvived
# 0      0  A/5 21171  7.25   NaN        S     True          False

# %%
# можно использовать функции для переименования
# переименовать в lower_case
tmp_df.rename(columns=str.lower).head(1)
# Out:
#    passengerid  survived  pclass   lname              name   sex   age  sibsp  \
# 0            1         0       1  Braund   Mr. Owen Harris  male  22.0      1
#
#    parch     ticket  fare cabin embarked  isadult  isadultsurvived
# 0      0  A/5 21171  7.25   NaN        S     True            False

# %%
# использование lambda функций
tmp_df['lower_case_name'] = tmp_df['Name'].apply(lambda x: x.lower())

# %%
tmp_df['lower_case_name']
# Out:
# 0                                  mr. owen harris
# 1       mrs. john bradley (florence briggs thayer)
# 2                                      miss. laina
# 3               mrs. jacques heath (lily may peel)
# 4                                mr. william henry
#                           ...
# 151                     mrs. thomas (edith wearne)
# 152                                    mr. alfonzo
# 153                              mr. austin blyler
# 154                                 mr. ole martin
# 155                              mr. charles duane
# Name: lower_case_name, Length: 156, dtype: object

# %%
# векторизированные функции для строк
tmp_df['lower_case_name'] = tmp_df['Name'].str.lower()

# %%
tmp_df['lower_case_name']
# Out:
# 0                                  mr. owen harris
# 1       mrs. john bradley (florence briggs thayer)
# 2                                      miss. laina
# 3               mrs. jacques heath (lily may peel)
# 4                                mr. william henry
#                           ...
# 151                     mrs. thomas (edith wearne)
# 152                                    mr. alfonzo
# 153                              mr. austin blyler
# 154                                 mr. ole martin
# 155                              mr. charles duane
# Name: lower_case_name, Length: 156, dtype: object
